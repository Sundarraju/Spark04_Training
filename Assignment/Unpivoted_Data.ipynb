# %%
sc
# Out:
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=2196045695913902#setting/sparkui/0912-140628-3uhxf31a/driver-8386986342459490162">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>

# %%
print(spark)

# %%
from pyspark.sql.functions import *

# %%
df1= spark.read.csv("dbfs:/FileStore/tables/Pyspark_Task.csv", header = True, inferSchema = True)
df1.printSchema()
df1.show()
# Out:
# root
#  |-- Product: string (nullable = true)
#  |-- Plant Name: string (nullable = true)
#  |-- Sales_18: integer (nullable = true)
#  |-- Sales_19: integer (nullable = true)
#  |-- Sales_20: integer (nullable = true)
#  |-- Sales_21: integer (nullable = true)
#  |-- Sales_22: integer (nullable = true)
#  |-- Inv_18: integer (nullable = true)
#  |-- Inv_19: integer (nullable = true)
#  |-- Inv_20: integer (nullable = true)
#  |-- Inv_21: integer (nullable = true)
#  |-- Inv_22: integer (nullable = true)
#
# +-------+----------+--------+--------+--------+--------+--------+------+------+------+------+------+
# |Product|Plant Name|Sales_18|Sales_19|Sales_20|Sales_21|Sales_22|Inv_18|Inv_19|Inv_20|Inv_21|Inv_22|
# +-------+----------+--------+--------+--------+--------+--------+------+------+------+------+------+
# |     P1|       PL1|   20000|   25000|   19000|   22000|   23000| 13000| 12000| 13000| 13500| 14000|
# ...

# %%
Unpivot = "stack(10, 'Sales_18', Sales_18, 'Sales_19', Sales_19, 'Sales_20', Sales_20, 'Sales_21', Sales_21, 'Sales_22', Sales_22, 'Inv_18', Inv_18, 'Inv_19', Inv_19, 'Inv_20', Inv_20, 'Inv_21', Inv_21, 'Inv_22', Inv_22) as (Metric,Value)"

# %%
df2 = df1.select("Product", "Plant Name",expr(Unpivot))
df2.show(60)
# Out:
# +-------+----------+--------+------+
# |Product|Plant Name|  Metric| Value|
# +-------+----------+--------+------+
# |     P1|       PL1|Sales_18| 20000|
# |     P1|       PL1|Sales_19| 25000|
# |     P1|       PL1|Sales_20| 19000|
# |     P1|       PL1|Sales_21| 22000|
# |     P1|       PL1|Sales_22| 23000|
# |     P1|       PL1|  Inv_18| 13000|
# |     P1|       PL1|  Inv_19| 12000|
# |     P1|       PL1|  Inv_20| 13000|
# |     P1|       PL1|  Inv_21| 13500|
# |     P1|       PL1|  Inv_22| 14000|
# |     P2|       PL1|Sales_18| 80000|
# |     P2|       PL1|Sales_19| 90000|
# |     P2|       PL1|Sales_20| 75000|
# |     P2|       PL1|Sales_21| 78000|
# |     P2|       PL1|Sales_22|100000|
# |     P2|       PL1|  Inv_18| 18000|
# |     P2|       PL1|  Inv_19| 18000|
# |     P2|       PL1|  Inv_20| 18000|
# |     P2|       PL1|  Inv_21| 18000|
# |     P2|       PL1|  Inv_22| 18000|
# |     P3|       PL3|Sales_18| 35000|
# |     P3|       PL3|Sales_19| 32000|
# ...
